# %%
import pandas as pd
import numpy as np
import os
import glob
import warnings
import gc
import joblib # Dùng để lưu OCSVM
import shutil # Dùng để dọn dẹp
import time 

# Thư viện cho Machine Learning
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, precision_recall_fscore_support, roc_auc_score, roc_curve, f1_score
from sklearn.svm import OneClassSVM
import xgboost as xgb

# Thư viện cho Deep Learning (PyTorch)
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

# Thư viện để vẽ biểu đồ
import matplotlib.pyplot as plt
import seaborn as sns

warnings.filterwarnings('ignore')

# --- Cấu hình Thiết bị ---
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Sử dụng thiết bị: {DEVICE}\n")
NUM_WORKERS = 4 if os.name == 'posix' else 0
print(f"Sử dụng {NUM_WORKERS} workers cho DataLoader.\n")

# --- Cấu hình Tên Thư Mục ---
UNSUPERVISED_TRAIN_DIR = 'unsupervised_train'
SUPERVISED_TRAIN_DIR = 'supervised_train_4labels'
TEST_DIR = 'test_all_4labels' 
MODEL_DIR = 'trained_models' # Thư mục lưu 4 model

# =================================================================
# ### THAY ĐỔI: Cập nhật CLASS_NAMES theo yêu cầu 5 nhãn (0-4) ###
# =================================================================
# Giả định thứ tự này. Nếu sai, bạn có thể chỉnh lại tên.
CLASS_NAMES = [
    'Benign',           # 0
    'DDoS',             # 1
    'DoS',              # 2
    'Merlin',           # 3
    'Reconnaisance',    # 4
]

# ===================================================================
# 1. CÁC HÀM HỖ TRỢ (Tải data, Giảm bộ nhớ)
# ===================================================================
def reduce_mem_usage(df, verbose=True):
    # ... (Hàm này giữ nguyên) ...
    start_mem = df.memory_usage().sum() / 1024**2
    for col in df.columns:
        col_type = df[col].dtype
        if col_type != object and col_type.name != 'category':
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)
            else:
                if c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
    end_mem = df.memory_usage().sum() / 1024**2
    if verbose:
        print(f'Bộ nhớ giảm từ {start_mem:.2f} MB xuống {end_mem:.2f} MB ({100 * (start_mem - end_mem) / start_mem:.1f}%)')
    return df

def load_data_from_parquet_directory(directory_path, drop_labels=False):
    print(f"Bắt đầu đọc dữ liệu từ thư mục: {directory_path}")
    all_files = glob.glob(os.path.join(directory_path, '*.parquet'))
    if not all_files:
        # Sửa lại: Dùng tên thư mục được truyền vào
        if directory_path == UNSUPERVISED_TRAIN_DIR:
             all_files = glob.glob(os.path.join('unsupervised_train', '*.parquet'))
        elif directory_path == SUPERVISED_TRAIN_DIR:
             all_files = glob.glob(os.path.join('supervised_train', '*.parquet'))
        
        if not all_files:
             print(f"⚠️ Lỗi: Không tìm thấy file .parquet nào trong '{directory_path}' hoặc thư mục thay thế.")
             return pd.DataFrame(), None # Trả về None cho labels
             
    df_chunks = []
    for i, file_path in enumerate(all_files):
        print(f"  ({i+1}/{len(all_files)}) Đang xử lý file: {os.path.basename(file_path)}...")
        chunk_df = pd.read_parquet(file_path)
        chunk_df.replace([np.inf, -np.inf], np.nan, inplace=True)
        # ### THAY ĐỔI: fillna(0) theo yêu cầu ###
        chunk_df.fillna(0, inplace=True) 
        df_chunks.append(chunk_df)
    
    print("Ghép các file đã xử lý...")
    if not df_chunks:
        return pd.DataFrame(), None # Xử lý trường hợp không có dữ liệu
    
    full_df = pd.concat(df_chunks, ignore_index=True)
    
    labels = {}
    if drop_labels:
        if 'Label' in full_df.columns:
            labels['Label'] = full_df.pop('Label')
        if 'Label_binary' in full_df.columns:
            labels['Label_binary'] = full_df.pop('Label_binary')
            
    full_df = reduce_mem_usage(full_df)
    del df_chunks
    gc.collect()
    
    if drop_labels:
        return full_df, labels
    else:
        return full_df, None # Trả về None cho labels

def plot_confusion_matrix(cm, classes, title='Confusion Matrix'):
    plt.figure(figsize=(12, 10))
    sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=classes, yticklabels=classes)
    plt.title(title, fontsize=16)
    plt.ylabel('Nhãn thực tế (True Label)', fontsize=12)
    plt.xlabel('Nhãn dự đoán (Predicted Label)', fontsize=12)
    plt.show()

# ===================================================================
# 2. CÁC LỚP MODEL & HÀM HUẤN LUYỆN (AE)
# ===================================================================
# ... (Class AnomalyAE và hàm train_model giữ nguyên) ...
class AnomalyAE(nn.Module):
    """
    Kiến trúc AE thống nhất (Input: 81D -> 32D).
    """
    def __init__(self, input_dim=81, latent_dim=32):
        super(AnomalyAE, self).__init__()
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, 512),
            nn.BatchNorm1d(512), nn.LeakyReLU(0.1), nn.Dropout(0.1),
            nn.Linear(512, 256),
            nn.BatchNorm1d(256), nn.LeakyReLU(0.1), nn.Dropout(0.1),
            nn.Linear(256, 128),
            nn.BatchNorm1d(128), nn.LeakyReLU(0.1), nn.Dropout(0.1),
            nn.Linear(128, 64),
            nn.BatchNorm1d(64), nn.LeakyReLU(0.1),
            nn.Linear(64, latent_dim)
        )
        self.decoder = nn.Sequential(
            nn.Linear(latent_dim, 64),
            nn.BatchNorm1d(64), nn.LeakyReLU(0.1),
            nn.Linear(64, 128),
            nn.BatchNorm1d(128), nn.LeakyReLU(0.1), nn.Dropout(0.1),
            nn.Linear(128, 256),
            nn.BatchNorm1d(256), nn.LeakyReLU(0.1), nn.Dropout(0.1),
            nn.Linear(256, 512),
            nn.BatchNorm1d(512), nn.LeakyReLU(0.1), nn.Dropout(0.1),
            nn.Linear(512, input_dim)
        )

    def forward(self, x):
        z = self.encoder(x)
        reconstructed = self.decoder(z)
        return reconstructed, z

def train_model(model, train_loader, val_loader, epochs, patience, learning_rate, weight_decay, model_save_path, loss_fn):
    model.to(DEVICE)
    criterion = loss_fn
    optimizer = optim.AdamW(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
    scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs)
    best_val_loss = float('inf')
    epochs_no_improve = 0
    print(f"Bắt đầu huấn luyện model '{model.__class__.__name__}' với loss '{criterion.__class__.__name__}'...")
    start_time = time.time()
    for epoch in range(epochs):
        model.train()
        epoch_train_loss = 0.0
        for (data,) in train_loader:
            data = data.to(DEVICE)
            optimizer.zero_grad()
            reconstructed, _ = model(data) # Lấy recon
            loss = criterion(reconstructed, data)
            loss.backward()
            optimizer.step()
            epoch_train_loss += loss.item() * data.size(0)
        avg_epoch_train_loss = epoch_train_loss / len(train_loader.dataset) if len(train_loader.dataset) > 0 else 0
        model.eval()
        val_loss = 0
        with torch.no_grad():
            for (data,) in val_loader:
                data = data.to(DEVICE)
                reconstructed, _ = model(data) # Lấy recon
                loss = criterion(reconstructed, data)
                val_loss += loss.item() * data.size(0)
        avg_val_loss = val_loss / len(val_loader.dataset) if len(val_loader.dataset) > 0 else 0
        scheduler.step()
        if (epoch + 1) % 10 == 0 or epoch == 0:
            print(f"Epoch {epoch+1}/{epochs} | Train Loss: {avg_epoch_train_loss:.6f} | Val Loss: {avg_val_loss:.6f} | LR: {optimizer.param_groups[0]['lr']:.2e}")
        if avg_val_loss < best_val_loss - 1e-6:
            best_val_loss = avg_val_loss
            torch.save(model.state_dict(), os.path.join(MODEL_DIR, model_save_path))
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1
        if epochs_no_improve >= patience:
            print(f"Early stopping được kích hoạt tại epoch {epoch+1}.")
            break
    end_time = time.time()
    best_loss_str = f"{best_val_loss:.6f}" if best_val_loss != float('inf') else "N/A"
    print(f"Huấn luyện hoàn tất trong {end_time - start_time:.2f} giây. Best Val Loss: {best_loss_str}.")
    print(f"Model tốt nhất đã lưu vào '{os.path.join(MODEL_DIR, model_save_path)}'.\n")
    try:
        model.load_state_dict(torch.load(os.path.join(MODEL_DIR, model_save_path)))
    except Exception as e: 
        print(f"Warning: Lỗi load model đã lưu: {e}. Sử dụng model cuối cùng.")
    return model

def get_latent_features(model, loader, device):
    model.eval()
    latent_features = []
    with torch.no_grad():
        for (data,) in loader:
            data = data.to(device)
            _, latent = model(data)
            latent_features.append(latent.cpu().numpy())
    return np.concatenate(latent_features, axis=0)

def get_reconstruction_errors(model, loader, loss_fn_eval, device):
    model.eval()
    errors = []
    with torch.no_grad():
        for (data,) in loader:
            data = data.to(device)
            reconstructed, _ = model(data)
            error_per_sample = torch.mean(loss_fn_eval(reconstructed, data), dim=1)
            errors.append(error_per_sample.cpu().numpy())
    return np.concatenate(errors)

# ===================================================================
# 3. HÀM MAIN (Thực thi Pipeline)
# ===================================================================

def main():
    
    # --- 0. Dọn dẹp và Tạo thư mục Model ---
    if os.path.exists(MODEL_DIR):
        print(f"Đang xóa thư mục model cũ: {MODEL_DIR}")
        shutil.rmtree(MODEL_DIR)
    os.makedirs(MODEL_DIR)
    print(f"Đã tạo thư mục model: {MODEL_DIR}\n")
    
    # --- 1. Tải Dữ Liệu Huấn Luyện ---
    print("="*20 + " BƯỚC 1: TẢI DỮ LIỆU HUẤN LUYỆN " + "="*20)
    
    # Tải data Benign (Không giám sát)
    X_unsup_train_df, _ = load_data_from_parquet_directory(UNSUPERVISED_TRAIN_DIR, drop_labels=False)
    # Tải data Full (Có giám sát)
    df_sup_train_full, _ = load_data_from_parquet_directory(SUPERVISED_TRAIN_DIR, drop_labels=False)
    
    if X_unsup_train_df.empty or df_sup_train_full.empty:
        print("Lỗi: Không thể tải dữ liệu huấn luyện. Dừng chương trình.")
        return

    # --- 2. Tiền xử lý (KHÔNG CÒN SCALER) ---
    print("\n" + "="*20 + " BƯỚC 2: TIỀN XỬ LÝ (Bỏ qua Scaler) " + "="*20)
    
    # ### THAY ĐỔI: Bỏ qua Scaler, chỉ fillna(0) ###
    X_unsup_train_df = X_unsup_train_df.fillna(0)
    X_unsup_train_scaled = X_unsup_train_df.values
    
    print("Đã tải dữ liệu Benign (giả định đã scale), fillna(0).")

    # Tạo Dataloader cho Pytorch (chỉ từ data Benign)
    BATCH_SIZE = 1024
    X_train_benign_split, X_val_benign_split = train_test_split(X_unsup_train_scaled, test_size=0.2, random_state=42)
    
    train_loader_benign_81d = DataLoader(TensorDataset(torch.FloatTensor(X_train_benign_split)), batch_size=BATCH_SIZE, shuffle=True, num_workers=NUM_WORKERS, pin_memory=True)
    val_loader_benign_81d = DataLoader(TensorDataset(torch.FloatTensor(X_val_benign_split)), batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS, pin_memory=True)
    train_loader_benign_full_no_shuffle = DataLoader(TensorDataset(torch.FloatTensor(X_unsup_train_scaled)), batch_size=BATCH_SIZE, shuffle=False)
    
    INPUT_DIM = X_unsup_train_scaled.shape[1]
    print(f"Phát hiện {INPUT_DIM} features.")
    
    
    # --- 3. Huấn luyện Pipeline Không Giám Sát (AE1, OCSVM, AE2) ---
    print("\n" + "="*20 + " BƯỚC 3: HUẤN LUYỆN PIPELINE KHÔNG GIÁM SÁT " + "="*20)
    
    # --- 3a: Huấn luyện AE1 (Feature Extractor) ---
    print("--- 3a: Huấn luyện AE1 (Feature Extractor) ---")
    ae1_feature_extractor = AnomalyAE(input_dim=INPUT_DIM, latent_dim=32)
    ae1_feature_extractor = train_model(ae1_feature_extractor, train_loader_benign_81d, val_loader_benign_81d,
                                 epochs=300, patience=50, learning_rate=5e-4,
                                 weight_decay=1e-6, model_save_path="best_ae1_extractor.pth",
                                 loss_fn=nn.MSELoss())

    # --- 3b: Huấn luyện OCSVM (Bộ lọc 1) ---
    print("--- 3b: Huấn luyện OCSVM (Bộ lọc 1) ---")
    print("Trích xuất đặc trưng 32D từ AE1 (Train)...")
    X_train_latent_32d = get_latent_features(ae1_feature_extractor, train_loader_benign_full_no_shuffle, DEVICE)
    
    # ### THAY ĐỔI: Bỏ qua Scaler 32D ###
    X_train_latent_scaled = X_train_latent_32d
    
    # =================================================================
    # ### THAY ĐỔI: Tăng nu để "hung hăng" hơn (Tối Đa Recall) ###
    # =================================================================
    NU_PARAM = 0.25 # Giả định 25% nhiễu/lỗi
    print(f"Huấn luyện OCSVM với nu = {NU_PARAM} trên dữ liệu 32D...")
    model_ocsvm = OneClassSVM(nu=NU_PARAM, kernel="rbf", gamma='scale', cache_size=2000)
    model_ocsvm.fit(X_train_latent_scaled)
    joblib.dump(model_ocsvm, os.path.join(MODEL_DIR, 'model_ocsvm.joblib'))
    print("Huấn luyện OCSVM hoàn tất.\n")

    # --- 3c: Huấn luyện AE2 (Bộ lọc 2 - 'Sạch') ---
    print("--- 3c: Huấn luyện AE2 (Bộ lọc 2 - 'Sạch') ---")
    ae2_final_filter = AnomalyAE(input_dim=INPUT_DIM, latent_dim=32)
    ae2_final_filter = train_model(ae2_final_filter, train_loader_benign_81d, val_loader_benign_81d,
                                   epochs=300, patience=50, learning_rate=1e-4,
                                   weight_decay=1e-6, model_save_path="best_ae2_filter.pth",
                                   loss_fn=nn.L1Loss())

    # --- 3d: Xác định Ngưỡng cho AE2 ---
    print("--- 3d: Xác định Ngưỡng AE2 ---")
    loss_fn_eval_ae2 = nn.L1Loss(reduction='none')
    print("Tính toán lỗi AE2 trên clean train full (81D)...")
    train_errors_ae2 = get_reconstruction_errors(ae2_final_filter, 
                                                 train_loader_benign_full_no_shuffle, 
                                                 loss_fn_eval_ae2, 
                                                 DEVICE)
    
    # =================================================================
    # ### THAY ĐỔI: Giảm quantile để "hung hăng" hơn (Tối Đa Recall) ###
    # =================================================================
    AE2_QUANTILE = 0.70 # Giảm từ 0.75 xuống 0.70
    threshold_ae2 = np.quantile(train_errors_ae2, AE2_QUANTILE)
    np.save(os.path.join(MODEL_DIR, 'ae2_threshold.npy'), threshold_ae2)
    print(f"Ngưỡng Lỗi AE2 (Quantile {AE2_QUANTILE*100}%): {threshold_ae2:.6f}\n")

    del X_unsup_train_df, X_unsup_train_scaled, X_train_benign_split, X_val_benign_split
    del X_train_latent_32d, X_train_latent_scaled, train_errors_ae2
    gc.collect()

    # --- 4. Huấn luyện XGBoost (Bộ lọc 3) ---
    print("\n" + "="*20 + " BƯỚC 4: HUẤN LUYỆN XGBOOST (BỘ LỌC 3) " + "="*20)
    
    # Lấy X và y từ data có giám sát
    y_sup_train = df_sup_train_full.pop('Label')
    X_sup_train = df_sup_train_full
    
    # ### THAY ĐỔI: Bỏ qua Scaler, chỉ fillna(0) ###
    X_sup_train = X_sup_train.fillna(0)
    X_sup_train_scaled = X_sup_train.values
    
    # Kiểm tra số lớp
    all_labels_sup = y_sup_train.unique()
    max_label_sup = int(np.max(all_labels_sup))
    num_classes = max_label_sup + 1 # XGBoost cần số lớp = max_label + 1
    
    # Cập nhật CLASS_NAMES nếu cần
    if (max_label_sup + 1) > len(CLASS_NAMES):
        CLASS_NAMES.extend([f"Unknown_{i}" for i in range(len(CLASS_NAMES), num_classes)])
    
    print(f"Phát hiện {len(all_labels_sup)} lớp, đặt num_class={num_classes} (từ 0 đến {max_label_sup})")
    
    # Chia Train/Val cho XGBoost
    X_train_xgb, X_val_xgb, y_train_xgb, y_val_xgb = train_test_split(
        X_sup_train_scaled, y_sup_train, test_size=0.2, stratify=y_sup_train, random_state=42
    )
    
    print(f"Kích thước tập Train XGBoost:   {X_train_xgb.shape}")
    print(f"Kích thước tập Val XGBoost:     {X_val_xgb.shape}")

    xgb_clf = xgb.XGBClassifier(
        objective="multi:softmax",
        num_class=num_classes, 
        eval_metric="mlogloss",
        random_state=42,
        n_estimators=2500,
        learning_rate=0.05,
        max_depth=10,
        subsample=1,
        colsample_bytree=1,
        tree_method="hist", 
        early_stopping_rounds=50,
        use_label_encoder=False
    )

    print("Bắt đầu training XGBoost...")
    xgb_clf.fit(
        X_train_xgb, y_train_xgb,
        eval_set=[(X_val_xgb, y_val_xgb)],
        verbose=100
    )
    
    xgb_clf.save_model(os.path.join(MODEL_DIR, 'xgb_classifier.json'))
    print(f"Đã lưu model XGBoost vào '{os.path.join(MODEL_DIR, 'xgb_classifier.json')}'\n")
    
    del X_sup_train, y_sup_train, X_sup_train_scaled, X_train_xgb, X_val_xgb, y_train_xgb, y_val_xgb
    gc.collect()

    # --- 5. Tải và Đánh giá trên Test Set ---
    print("\n" + "="*20 + " BƯỚC 5: TẢI VÀ ĐÁNH GIÁ TRÊN TEST SET " + "="*20)
    
    df_test, test_labels = load_data_from_parquet_directory(TEST_DIR, drop_labels=True)
    
    if df_test.empty:
        print(f"Lỗi: Không tìm thấy dữ liệu test trong '{TEST_DIR}'. Dừng.")
        return
        
    y_test_binary = test_labels['Label_binary'] # Nhãn 0/1
    y_test_multi = test_labels['Label']         # Nhãn đa lớp
    
    # ### THAY ĐỔI: Bỏ qua Scaler, chỉ fillna(0) ###
    df_test = df_test.fillna(0)
    X_test_scaled = df_test.values
    
    print(f"Kích thước Test Set: {X_test_scaled.shape}")
    
    # --- 6. Thực thi Pipeline 3 Giai Đoạn ---
    print("\n" + "="*20 + " BƯỚC 6: THỰC THI PIPELINE 3 GIAI ĐOẠN " + "="*20)
    
    # Tạo Dataloader cho Test Set
    test_loader = DataLoader(TensorDataset(torch.FloatTensor(X_test_scaled)), 
                             batch_size=BATCH_SIZE, shuffle=False)

    # 6a. Lấy dự đoán GĐ 1 (OCSVM)
    print("Test (Bước 6a): Đang lấy latent features 32D...")
    X_test_latent_32d = get_latent_features(ae1_feature_extractor, test_loader, DEVICE)
    # ### THAY ĐỔI: Bỏ qua Scaler 32D ###
    X_test_latent_scaled = X_test_latent_32d
    
    print("Test (Bước 6b): Đang dự đoán bằng OCSVM (Bộ lọc 1)...")
    y_pred_ocsvm_raw = model_ocsvm.predict(X_test_latent_scaled)
    y_pred_ocsvm = np.array([0 if p == 1 else 1 for p in y_pred_ocsvm_raw])
    print(f"OCSVM phát hiện: {np.sum(y_pred_ocsvm)} bất thường.")

    # 6b. Lấy dự đoán GĐ 2 (AE2)
    print("Test (Bước 6c): Đang dự đoán bằng AE2 (Bộ lọc 2)...")
    loss_fn_eval_ae2 = nn.L1Loss(reduction='none')
    test_errors_ae2 = get_reconstruction_errors(ae2_final_filter, 
                                                 test_loader, 
                                                 loss_fn_eval_ae2, 
                                                 DEVICE)
    y_pred_ae2 = (test_errors_ae2 > threshold_ae2).astype(int)
    print(f"AE2 phát hiện: {np.sum(y_pred_ae2)} bất thường.")

    # 6c. Lấy "Cờ Bất Thường" (Unsupervised Flag)
    # Bất thường (1) nếu OCSVM HOẶC AE2 nói là bất thường
    unsupervised_flag = np.logical_or(y_pred_ocsvm, y_pred_ae2).astype(int)
    abnormal_indices = np.where(unsupervised_flag == 1)[0]
    print(f"Tổng số mẫu bị gắn cờ bất thường (GĐ 1+2): {len(abnormal_indices)}")

    # 6d. Lấy dự đoán GĐ 3 (XGBoost)
    if len(abnormal_indices) > 0:
        print("Test (Bước 6d): Đưa các mẫu bất thường vào XGBoost (Bộ lọc 3)...")
        X_test_to_xgb = X_test_scaled[abnormal_indices]
        y_pred_xgb_multi = xgb_clf.predict(X_test_to_xgb)
    else:
        print("Test (Bước 6d): Không có mẫu bất thường nào, bỏ qua XGBoost.")
        y_pred_xgb_multi = np.array([]) # Mảng rỗng

    # 6e. Tạo mảng dự đoán cuối cùng (Final Prediction)
    # Mặc định tất cả là Benign (0)
    y_pred_final = np.zeros_like(y_test_multi)
    # Ghi đè các mẫu bất thường bằng dự đoán của XGBoost
    y_pred_final[abnormal_indices] = y_pred_xgb_multi
    
    # --- 7. Đánh Giá Toàn Bộ Hệ Thống ---
    print("\n" + "="*20 + " BƯỚC 7: ĐÁNH GIÁ TOÀN BỘ HỆ THỐNG " + "="*20)
    
    print("\n--- 7a. Đánh giá Pipeline Không Giám Sát (GĐ 1+2) ---")
    print("(So sánh cờ 0/1 với 'Label_binary' thật)")
    
    # ### THÊM MỚI: In và Vẽ CM cho GĐ 1+2 ###
    print("\nMa trận nhầm lẫn (Pipeline Không Giám Sát):")
    cm_unsup = confusion_matrix(y_test_binary, unsupervised_flag)
    print(cm_unsup)
    
    print("\nBáo cáo phân loại (Pipeline Không Giám Sát):")
    binary_class_names = ['Benign (0)', 'Abnormal (1)']
    print(classification_report(y_test_binary, unsupervised_flag, target_names=binary_class_names))
    
    print("\nĐang vẽ ma trận nhầm lẫn (Không Giám Sát)...")
    plot_confusion_matrix(cm_unsup, classes=binary_class_names, title='Ma trận nhầm lẫn (GĐ 1+2 Không Giám Sát)')
    
    # ----------------------------------------------
    
    print("\n--- 7b. Đánh giá Toàn Bộ Pipeline (GĐ 1+2+3) ---")
    print("(So sánh nhãn đa lớp với 'Label' thật)")
    
    # Lấy tên lớp chính xác dựa trên các nhãn đã thấy
    final_labels_present = np.unique(np.concatenate((y_test_multi, y_pred_final)))
    
    # ### THAY ĐỔI: Lọc CLASS_NAMES dựa trên các nhãn THỰC TẾ có trong dữ liệu ###
    final_class_names = [CLASS_NAMES[i] for i in final_labels_present if i < len(CLASS_NAMES)]
    # Lọc ra các nhãn không có tên (ví dụ nếu CLASS_NAMES bị thiếu)
    valid_labels = [i for i in final_labels_present if i < len(CLASS_NAMES)]
    
    print(classification_report(y_test_multi, y_pred_final, target_names=final_class_names, labels=valid_labels, zero_division=0))
    
    # Vẽ Ma trận nhầm lẫn cuối cùng
    print("\nĐang vẽ ma trận nhầm lẫn cuối cùng...")
    cm_final = confusion_matrix(y_test_multi, y_pred_final, labels=valid_labels)
    plot_confusion_matrix(cm_final, classes=final_class_names, title='Ma trận nhầm lẫn Pipeline 3 Giai Đoạn (Tổng thể)')
    
    # --- 8. Đánh giá riêng XGBoost (Độ hiệu quả của GĐ 3) ---
    print("\n" + "="*20 + " BƯỚC 8: ĐÁNH GIÁ RIÊNG XGBOOST (GĐ 3) " + "="*20)
    
    # Chúng ta chỉ quan tâm đến các mẫu THỰC SỰ là bất thường
    true_abnormal_indices = np.where(y_test_multi != 0)[0]
    
    if len(true_abnormal_indices) > 0:
        # Lấy nhãn thật và nhãn dự đoán CHỈ của các mẫu bất thường
        y_true_abnormal_only = y_test_multi[true_abnormal_indices]
        y_pred_abnormal_only = y_pred_final[true_abnormal_indices]
        
        # Lấy tên các lớp TẤN CÔNG (bỏ 'Benign')
        attack_labels = [l for l in valid_labels if l != 0]
        attack_class_names = [CLASS_NAMES[i] for i in attack_labels]
        
        print("Đánh giá khả năng phân loại của XGBoost (Chỉ trên các mẫu bất thường thật):")
        if not attack_labels:
             print("Không có nhãn tấn công nào được phát hiện hoặc có trong tên lớp.")
        else:
            print(classification_report(y_true_abnormal_only, y_pred_abnormal_only, target_names=attack_class_names, labels=attack_labels, zero_division=0))
            
            cm_xgb = confusion_matrix(y_true_abnormal_only, y_pred_abnormal_only, labels=attack_labels)
            plot_confusion_matrix(cm_xgb, classes=attack_class_names, title='Ma trận nhầm lẫn XGBoost (Chỉ trên các mẫu bất thường)')
    else:
        print("Không có mẫu bất thường thật nào trong test set để đánh giá XGBoost.")

# --- Chạy hàm main ---
if __name__ == '__main__':
    main()
# Out:
# Sử dụng thiết bị: cuda
#
# Sử dụng 4 workers cho DataLoader.
#
# Đang xóa thư mục model cũ: trained_models
# Đã tạo thư mục model: trained_models
#
# ==================== BƯỚC 1: TẢI DỮ LIỆU HUẤN LUYỆN ====================
# Bắt đầu đọc dữ liệu từ thư mục: unsupervised_train
#   (1/1) Đang xử lý file: part.0.parquet...
# Ghép các file đã xử lý...
# Bộ nhớ giảm từ 212.35 MB xuống 103.23 MB (51.4%)
# Bắt đầu đọc dữ liệu từ thư mục: supervised_train_4labels
#   (1/11) Đang xử lý file: part.6.parquet...
#   (2/11) Đang xử lý file: part.2.parquet...
#   (3/11) Đang xử lý file: part.7.parquet...
#   (4/11) Đang xử lý file: part.1.parquet...
#   (5/11) Đang xử lý file: part.8.parquet...
#   (6/11) Đang xử lý file: part.4.parquet...
#   (7/11) Đang xử lý file: part.0.parquet...
#   (8/11) Đang xử lý file: part.3.parquet...
#   (9/11) Đang xử lý file: part.9.parquet...
#   (10/11) Đang xử lý file: part.5.parquet...
#   (11/11) Đang xử lý file: part.10.parquet...
# Ghép các file đã xử lý...
# Bộ nhớ giảm từ 5772.74 MB xuống 2780.77 MB (51.8%)
#
# ==================== BƯỚC 2: TIỀN XỬ LÝ (Bỏ qua Scaler) ====================
# Đã tải dữ liệu Benign (giả định đã scale), fillna(0).
# Phát hiện 81 features.
#
# ==================== BƯỚC 3: HUẤN LUYỆN PIPELINE KHÔNG GIÁM SÁT ====================
# --- 3a: Huấn luyện AE1 (Feature Extractor) ---
# Bắt đầu huấn luyện model 'AnomalyAE' với loss 'MSELoss'...
# Epoch 1/300 | Train Loss: 0.708877 | Val Loss: 0.082783 | LR: 5.00e-04
# Epoch 10/300 | Train Loss: 0.054272 | Val Loss: 0.019021 | LR: 4.99e-04
# Epoch 20/300 | Train Loss: 0.043124 | Val Loss: 0.012745 | LR: 4.95e-04
# Epoch 30/300 | Train Loss: 0.038202 | Val Loss: 0.011187 | LR: 4.88e-04
# Epoch 40/300 | Train Loss: 0.034730 | Val Loss: 0.009730 | LR: 4.78e-04
# Epoch 50/300 | Train Loss: 0.032467 | Val Loss: 0.008988 | LR: 4.67e-04
# Epoch 60/300 | Train Loss: 0.030998 | Val Loss: 0.007640 | LR: 4.52e-04
# Epoch 70/300 | Train Loss: 0.029721 | Val Loss: 0.006559 | LR: 4.36e-04
# Epoch 80/300 | Train Loss: 0.029113 | Val Loss: 0.006455 | LR: 4.17e-04
# Epoch 90/300 | Train Loss: 0.027988 | Val Loss: 0.005873 | LR: 3.97e-04
# Epoch 100/300 | Train Loss: 0.027394 | Val Loss: 0.005950 | LR: 3.75e-04
# Epoch 110/300 | Train Loss: 0.026821 | Val Loss: 0.005875 | LR: 3.52e-04
# Epoch 120/300 | Train Loss: 0.026184 | Val Loss: 0.005634 | LR: 3.27e-04
# Epoch 130/300 | Train Loss: 0.025943 | Val Loss: 0.005056 | LR: 3.02e-04
# Epoch 140/300 | Train Loss: 0.025364 | Val Loss: 0.005353 | LR: 2.76e-04
# Epoch 150/300 | Train Loss: 0.024765 | Val Loss: 0.004842 | LR: 2.50e-04
# Epoch 160/300 | Train Loss: 0.024638 | Val Loss: 0.004550 | LR: 2.24e-04
# Epoch 170/300 | Train Loss: 0.024340 | Val Loss: 0.004472 | LR: 1.98e-04
# Epoch 180/300 | Train Loss: 0.024083 | Val Loss: 0.004460 | LR: 1.73e-04
# Epoch 190/300 | Train Loss: 0.023818 | Val Loss: 0.004471 | LR: 1.48e-04
# Epoch 200/300 | Train Loss: 0.023588 | Val Loss: 0.004355 | LR: 1.25e-04
# Epoch 210/300 | Train Loss: 0.023414 | Val Loss: 0.004190 | LR: 1.03e-04
# Epoch 220/300 | Train Loss: 0.023127 | Val Loss: 0.004506 | LR: 8.27e-05
# Epoch 230/300 | Train Loss: 0.023062 | Val Loss: 0.004055 | LR: 6.42e-05
# Epoch 240/300 | Train Loss: 0.022998 | Val Loss: 0.004061 | LR: 4.77e-05
# Epoch 250/300 | Train Loss: 0.022816 | Val Loss: 0.004072 | LR: 3.35e-05
# Epoch 260/300 | Train Loss: 0.022669 | Val Loss: 0.003950 | LR: 2.16e-05
# Epoch 270/300 | Train Loss: 0.022735 | Val Loss: 0.004110 | LR: 1.22e-05
# Epoch 280/300 | Train Loss: 0.022633 | Val Loss: 0.003736 | LR: 5.46e-06
# Epoch 290/300 | Train Loss: 0.022570 | Val Loss: 0.004044 | LR: 1.37e-06
# Epoch 300/300 | Train Loss: 0.022616 | Val Loss: 0.003886 | LR: 0.00e+00
# Huấn luyện hoàn tất trong 493.04 giây. Best Val Loss: 0.003708.
# Model tốt nhất đã lưu vào 'trained_models/best_ae1_extractor.pth'.
#
# --- 3b: Huấn luyện OCSVM (Bộ lọc 1) ---
# Trích xuất đặc trưng 32D từ AE1 (Train)...
# Huấn luyện OCSVM với nu = 0.25 trên dữ liệu 32D...
# Huấn luyện OCSVM hoàn tất.
#
# --- 3c: Huấn luyện AE2 (Bộ lọc 2 - 'Sạch') ---
# Bắt đầu huấn luyện model 'AnomalyAE' với loss 'L1Loss'...
# Epoch 1/300 | Train Loss: 0.547505 | Val Loss: 0.267320 | LR: 1.00e-04
# Epoch 10/300 | Train Loss: 0.145576 | Val Loss: 0.078840 | LR: 9.97e-05
# Epoch 20/300 | Train Loss: 0.124203 | Val Loss: 0.065405 | LR: 9.89e-05
# Epoch 30/300 | Train Loss: 0.114388 | Val Loss: 0.057160 | LR: 9.76e-05
# Epoch 40/300 | Train Loss: 0.108207 | Val Loss: 0.053578 | LR: 9.57e-05
# Epoch 50/300 | Train Loss: 0.103901 | Val Loss: 0.051788 | LR: 9.33e-05
# Epoch 60/300 | Train Loss: 0.100355 | Val Loss: 0.047835 | LR: 9.05e-05
# Epoch 70/300 | Train Loss: 0.097947 | Val Loss: 0.044354 | LR: 8.72e-05
# Epoch 80/300 | Train Loss: 0.095859 | Val Loss: 0.043772 | LR: 8.35e-05
# Epoch 90/300 | Train Loss: 0.094402 | Val Loss: 0.043872 | LR: 7.94e-05
# Epoch 100/300 | Train Loss: 0.092698 | Val Loss: 0.042478 | LR: 7.50e-05
# Epoch 110/300 | Train Loss: 0.092044 | Val Loss: 0.041151 | LR: 7.03e-05
# Epoch 120/300 | Train Loss: 0.090783 | Val Loss: 0.040296 | LR: 6.55e-05
# Epoch 130/300 | Train Loss: 0.089926 | Val Loss: 0.040830 | LR: 6.04e-05
# Epoch 140/300 | Train Loss: 0.089298 | Val Loss: 0.038711 | LR: 5.52e-05
# Epoch 150/300 | Train Loss: 0.088523 | Val Loss: 0.039615 | LR: 5.00e-05
# Epoch 160/300 | Train Loss: 0.087729 | Val Loss: 0.039051 | LR: 4.48e-05
# Epoch 170/300 | Train Loss: 0.087154 | Val Loss: 0.037591 | LR: 3.96e-05
# Epoch 180/300 | Train Loss: 0.086799 | Val Loss: 0.037204 | LR: 3.45e-05
# Epoch 190/300 | Train Loss: 0.086530 | Val Loss: 0.037196 | LR: 2.97e-05
# Epoch 200/300 | Train Loss: 0.086119 | Val Loss: 0.036407 | LR: 2.50e-05
# Epoch 210/300 | Train Loss: 0.085946 | Val Loss: 0.037601 | LR: 2.06e-05
# Epoch 220/300 | Train Loss: 0.085767 | Val Loss: 0.037125 | LR: 1.65e-05
# Epoch 230/300 | Train Loss: 0.085389 | Val Loss: 0.036526 | LR: 1.28e-05
# Epoch 240/300 | Train Loss: 0.085330 | Val Loss: 0.036006 | LR: 9.55e-06
# Epoch 250/300 | Train Loss: 0.085366 | Val Loss: 0.035910 | LR: 6.70e-06
# Epoch 260/300 | Train Loss: 0.085075 | Val Loss: 0.035813 | LR: 4.32e-06
# Epoch 270/300 | Train Loss: 0.084989 | Val Loss: 0.035690 | LR: 2.45e-06
# Early stopping được kích hoạt tại epoch 273.
# Huấn luyện hoàn tất trong 458.32 giây. Best Val Loss: 0.034768.
# Model tốt nhất đã lưu vào 'trained_models/best_ae2_filter.pth'.
#
# --- 3d: Xác định Ngưỡng AE2 ---
# Tính toán lỗi AE2 trên clean train full (81D)...
# Ngưỡng Lỗi AE2 (Quantile 70.0%): 0.029191
#
#
# ==================== BƯỚC 4: HUẤN LUYỆN XGBOOST (BỘ LỌC 3) ====================
# Phát hiện 5 lớp, đặt num_class=5 (từ 0 đến 4)
# Kích thước tập Train XGBoost:   (7381893, 81)
# Kích thước tập Val XGBoost:     (1845474, 81)
# Bắt đầu training XGBoost...
# [0]	validation_0-mlogloss:1.49404
# [100]	validation_0-mlogloss:0.07379
# [200]	validation_0-mlogloss:0.05908
# [300]	validation_0-mlogloss:0.05483
# [400]	validation_0-mlogloss:0.05261
# [500]	validation_0-mlogloss:0.05127
# [600]	validation_0-mlogloss:0.05041
# [700]	validation_0-mlogloss:0.04975
# [800]	validation_0-mlogloss:0.04927
# [900]	validation_0-mlogloss:0.04892
# [1000]	validation_0-mlogloss:0.04862
# [1100]	validation_0-mlogloss:0.04840
# [1200]	validation_0-mlogloss:0.04821
# [1300]	validation_0-mlogloss:0.04807
# [1400]	validation_0-mlogloss:0.04795
# [1500]	validation_0-mlogloss:0.04782
# [1600]	validation_0-mlogloss:0.04774
# [1700]	validation_0-mlogloss:0.04768
# [1800]	validation_0-mlogloss:0.04762
# [1900]	validation_0-mlogloss:0.04757
# [2000]	validation_0-mlogloss:0.04752
# [2100]	validation_0-mlogloss:0.04750
# [2200]	validation_0-mlogloss:0.04748
# [2300]	validation_0-mlogloss:0.04747
# [2400]	validation_0-mlogloss:0.04746
# [2499]	validation_0-mlogloss:0.04746
# Đã lưu model XGBoost vào 'trained_models/xgb_classifier.json'
#
#
# ==================== BƯỚC 5: TẢI VÀ ĐÁNH GIÁ TRÊN TEST SET ====================
# Bắt đầu đọc dữ liệu từ thư mục: test_all_4labels
#   (1/11) Đang xử lý file: part.6.parquet...
#   (2/11) Đang xử lý file: part.2.parquet...
#   (3/11) Đang xử lý file: part.7.parquet...
#   (4/11) Đang xử lý file: part.1.parquet...
#   (5/11) Đang xử lý file: part.8.parquet...
#   (6/11) Đang xử lý file: part.4.parquet...
#   (7/11) Đang xử lý file: part.0.parquet...
#   (8/11) Đang xử lý file: part.3.parquet...
#   (9/11) Đang xử lý file: part.9.parquet...
#   (10/11) Đang xử lý file: part.5.parquet...
#   (11/11) Đang xử lý file: part.10.parquet...
# Ghép các file đã xử lý...
# Bộ nhớ giảm từ 1006.29 MB xuống 489.17 MB (51.4%)
# Kích thước Test Set: (1628348, 81)
#
# ==================== BƯỚC 6: THỰC THI PIPELINE 3 GIAI ĐOẠN ====================
# Test (Bước 6a): Đang lấy latent features 32D...
# Test (Bước 6b): Đang dự đoán bằng OCSVM (Bộ lọc 1)...
# OCSVM phát hiện: 1186289 bất thường.
# Test (Bước 6c): Đang dự đoán bằng AE2 (Bộ lọc 2)...
# AE2 phát hiện: 1560093 bất thường.
# Tổng số mẫu bị gắn cờ bất thường (GĐ 1+2): 1565045
# Test (Bước 6d): Đưa các mẫu bất thường vào XGBoost (Bộ lọc 3)...
#
# ==================== BƯỚC 7: ĐÁNH GIÁ TOÀN BỘ HỆ THỐNG ====================
#
# --- 7a. Đánh giá Pipeline Không Giám Sát (GĐ 1+2) ---
# (So sánh cờ 0/1 với 'Label_binary' thật)
#
# Ma trận nhầm lẫn (Pipeline Không Giám Sát):
# [[  39437   21202]
#  [  23866 1543843]]
#
# Báo cáo phân loại (Pipeline Không Giám Sát):
#               precision    recall  f1-score   support
#
#   Benign (0)       0.62      0.65      0.64     60639
# Abnormal (1)       0.99      0.98      0.99   1567709
#
#     accuracy                           0.97   1628348
#    macro avg       0.80      0.82      0.81   1628348
# weighted avg       0.97      0.97      0.97   1628348
#
#
# Đang vẽ ma trận nhầm lẫn (Không Giám Sát)...
# --- 7b. Đánh giá Toàn Bộ Pipeline (GĐ 1+2+3) ---
# (So sánh nhãn đa lớp với 'Label' thật)
#                precision    recall  f1-score   support
#
#        Benign       0.69      0.98      0.81     60639
#          DDoS       0.99      0.98      0.99    927457
#           DoS       0.99      0.98      0.98    534384
#        Merlin       1.00      0.98      0.99      9080
# Reconnaisance       0.98      0.87      0.92     96788
#
#      accuracy                           0.98   1628348
#     macro avg       0.93      0.96      0.94   1628348
#  weighted avg       0.98      0.98      0.98   1628348
#
#
# Đang vẽ ma trận nhầm lẫn cuối cùng...
# ==================== BƯỚC 8: ĐÁNH GIÁ RIÊNG XGBOOST (GĐ 3) ====================
# Đánh giá khả năng phân loại của XGBoost (Chỉ trên các mẫu bất thường thật):
#                precision    recall  f1-score   support
#
#          DDoS       0.99      0.98      0.99    927457
#           DoS       0.99      0.98      0.98    534384
#        Merlin       1.00      0.98      0.99      9080
# Reconnaisance       0.98      0.87      0.92     96788
#
#     micro avg       0.99      0.97      0.98   1567709
#     macro avg       0.99      0.95      0.97   1567709
#  weighted avg       0.99      0.97      0.98   1567709
